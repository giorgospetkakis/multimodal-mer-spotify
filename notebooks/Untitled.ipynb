# %%
import pandas as pd
import numpy as np
import os
import lyricsgenius
from numpy import genfromtxt
code = "rBHhTGeCNOkKE03UljXrT142_zhznolRuHooknJDrJGx0AZCkauikphIaX7Abxy4"
genius = lyricsgenius.Genius(code)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-176298f096dc> in <module>
#       2 import numpy as np
#       3 import os
# ----> 4 import nltk.metrics.distance.edit_distance
#       5 import lyricsgenius
#       6 from numpy import genfromtxt
#
# ModuleNotFoundError: No module named 'nltk.metrics.distance.edit_distance'; 'nltk.metrics.distance' is not a package

# %%
cwd = os.getcwd()
print(cwd)
def levenshteinDistance(s1, s2):
    if len(s1) > len(s2):
        s1, s2 = s2, s1

    distances = range(len(s1) + 1)
    for i2, c2 in enumerate(s2):
        distances_ = [i2+1]
        for i1, c1 in enumerate(s1):
            if c1 == c2:
                distances_.append(distances[i1])
            else:
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
        distances = distances_
    return distances[-1]
# Out:
# C:\DATA\Google Drive\KU\Semester 2\Cognitive Science 2\project\spotify\CS2
# 2

# %%
my_data = pd.read_csv('data/raw/SpotifyData.csv')
songs = [0] * my_data.shape[0]

# %%
for i in range(my_data.shape[0]):
    if songs[i] == 0:
        song = genius.search_song(my_data.iloc[i].title,my_data.iloc[i].artist)
        if song is not None:
                if levenshteinDistance(my_data.iloc[i].title.lower(), song.title.lower()) <= 3 and levenshteinDistance(my_data.iloc[i].artist.lower(),song.artist.lower()) <=3 :
                    songs[i] = song
                    print("added "+ song.title)
                else:
                    print("not added ", song.artist, song.title)
# Out:
# Searching for "i want your sex" by george michael...
# Specified song does not have a valid URL with lyrics. Rejecting.
# Searching for "silence is golden" by garbage...
# Specified song does not have a valid URL with lyrics. Rejecting.
# Searching for "my gun go off" by 50 cent...
# Specified song does not have a valid URL with lyrics. Rejecting.
# Searching for "mamacita" by collie buddz...
# Specified song does not have a valid URL with lyrics. Rejecting.
# Searching for "coming home" by avenged sevenfold...
# Specified song does not have a valid URL with lyrics. Rejecting.
# Searching for "illusion" by creed...
# Done.
# added Illusion
# Searching for "dont give up" by the whitest boy alive...
# Specified song does not have a valid URL with lyrics. Rejecting.
# Searching for "wherever you are" by ulrich schnauss...
# Done.
# added Wherever You Are
# Searching for "poor thing" by helena bonham carter  johnny depp...
# Done.
# not added  Various Artists Poor Thing
# ...

# %%
import codecs
for i in range(0,len(songs)):
    if songs[i] != 0:
        song = songs[i]
        filename = "data/lyrics/"+str(i)+".txt"
        with codecs.open(filename, 'w', 'utf-8') as file:
            file.write(song.lyrics)

# %%
for i in range(my_data.shape[0]):
    if songs[i] == 0:
        song = genius.search_song(my_data.iloc[i].title,my_data.iloc[i].artist)
        if song is not None:
                if levenshteinDistance(my_data.iloc[i].title.lower(), song.title.lower()) <= 3 and levenshteinDistance(my_data.iloc[i].artist.lower(),song.artist.lower()) <=3 :
                    songs[i] = song
                    print("added "+ song.title)
                else:
                    print("not added ", song.artist, song.title)

# %%
for i in range(my_data.shape[0]):
    if songs[i] == 0:
        song = genius.search_song(my_data.iloc[i].title,my_data.iloc[i].artist)
        if song is not None:
                if levenshteinDistance(my_data.iloc[i].title.lower(), song.title.lower()) <= 3 and levenshteinDistance(my_data.iloc[i].artist.lower(),song.artist.lower()) <=3 :
                    songs[i] = song
                    print("added "+ song.title)
                else:
                    print("not added ", song.artist, song.title)

# %%
c = 0
for i in songs:
    if i != 0:
        c+=1
c
# Out:
# 253
